# %%
from __future__ import print_function

import numpy as np
import tensorflow as tf
from tensorflow.contrib import rnn
import random
import collections
import time

start_time = time.time()
def elapsed(sec):
    if sec<60:
        return str(sec) + " sec"
    elif sec<(60*60):
        return str(sec/60) + " min"
    else:
        return str(sec/(60*60)) + " hr"


# Target log path
logs_path = '/tmp/tensorflow/rnn_words'
writer = tf.summary.FileWriter(logs_path)

# Text file containing words for training
training_file = 'belling_the_cat.txt'

def read_data(fname):
    with open(fname) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    content = [content[i].split() for i in range(len(content))]
    content = np.array(content)
    content = np.reshape(content, [-1, ])
    return content

training_data = read_data(training_file)
print("Loaded training data...")

def build_dataset(words):
    count = collections.Counter(words).most_common()
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

dictionary, reverse_dictionary = build_dataset(training_data)
vocab_size = len(dictionary)
# Out:
# Loaded training data...

# %%
# Parameters
learning_rate = 0.001
training_iters = 50000
display_step = 1000
n_input = 3

# number of units in RNN cell
n_hidden = 512

# tf Graph input
x = tf.placeholder("float", [None, n_input, 1])
y = tf.placeholder("float", [None, vocab_size])

# RNN output node weights and biases
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, vocab_size]))
}
biases = {
    'out': tf.Variable(tf.random_normal([vocab_size]))
}

def RNN(x, weights, biases):

    # reshape to [1, n_input]
    x = tf.reshape(x, [-1, n_input])

    # Generate a n_input-element sequence of inputs
    # (eg. [had] [a] [general] -> [20] [6] [33])
    x = tf.split(x,n_input,1)

    # 2-layer LSTM, each layer has n_hidden units.
    # Average Accuracy= 95.20% at 50k iter
    rnn_cell = rnn.MultiRNNCell([rnn.BasicLSTMCell(n_hidden),rnn.BasicLSTMCell(n_hidden)])

    # 1-layer LSTM with n_hidden units but with lower accuracy.
    # Average Accuracy= 90.60% 50k iter
    # Uncomment line below to test but comment out the 2-layer rnn.MultiRNNCell above
    # rnn_cell = rnn.BasicLSTMCell(n_hidden)

    # generate prediction
    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # there are n_input outputs but
    # we only want the last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %%
pred = RNN(x, weights, biases)

# Loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

# Model evaluation
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as session:
    session.run(init)
    step = 0
    offset = random.randint(0,n_input+1)
    end_offset = n_input + 1
    acc_total = 0
    loss_total = 0

    writer.add_graph(session.graph)

    while step < training_iters:
        # Generate a minibatch. Add some randomness on selection process.
        if offset > (len(training_data)-end_offset):
            offset = random.randint(0, n_input+1)

        symbols_in_keys = [ [dictionary[ str(training_data[i])]] for i in range(offset, offset+n_input) ]
        symbols_in_keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])

        symbols_out_onehot = np.zeros([vocab_size], dtype=float)
        symbols_out_onehot[dictionary[str(training_data[offset+n_input])]] = 1.0
        symbols_out_onehot = np.reshape(symbols_out_onehot,[1,-1])

        _, acc, loss, onehot_pred = session.run([optimizer, accuracy, cost, pred], \
                                                feed_dict={x: symbols_in_keys, y: symbols_out_onehot})
        loss_total += loss
        acc_total += acc
        if (step+1) % display_step == 0:
            print("Iter= " + str(step+1) + ", Average Loss= " + \
                  "{:.6f}".format(loss_total/display_step) + ", Average Accuracy= " + \
                  "{:.2f}%".format(100*acc_total/display_step))
            acc_total = 0
            loss_total = 0
            symbols_in = [training_data[i] for i in range(offset, offset + n_input)]
            symbols_out = training_data[offset + n_input]
            symbols_out_pred = reverse_dictionary[int(tf.argmax(onehot_pred, 1).eval())]
            print("%s - [%s] vs [%s]" % (symbols_in,symbols_out,symbols_out_pred))
        step += 1
        offset += (n_input+1)
    print("Optimization Finished!")
    print("Elapsed time: ", elapsed(time.time() - start_time))
    print("Run on command line.")
    print("\ttensorboard --logdir=%s" % (logs_path))
    print("Point your web browser to: http://localhost:6006/")
    while True:
        prompt = "%s words: " % n_input
        sentence = input(prompt)
        sentence = sentence.strip()
        words = sentence.split(' ')
        if len(words) != n_input:
            continue
        try:
            symbols_in_keys = [dictionary[str(words[i])] for i in range(len(words))]
            for i in range(32):
                keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])
                onehot_pred = session.run(pred, feed_dict={x: keys})
                onehot_pred_index = int(tf.argmax(onehot_pred, 1).eval())
                sentence = "%s %s" % (sentence,reverse_dictionary[onehot_pred_index])
                symbols_in_keys = symbols_in_keys[1:]
                symbols_in_keys.append(onehot_pred_index)
            print(sentence)
        except:
            print("Word not in dictionary")
# Out:
# Iter= 1000, Average Loss= 4.509226, Average Accuracy= 4.00%
# ['the', 'old', 'mouse'] - [said] vs [a]
# Iter= 2000, Average Loss= 2.849255, Average Accuracy= 18.10%
# ['cat', '?', 'the'] - [mice] vs [mice]
# Iter= 3000, Average Loss= 2.252144, Average Accuracy= 40.70%
# ['until', 'an', 'old'] - [mouse] vs [mouse]
# Iter= 4000, Average Loss= 1.791564, Average Accuracy= 55.50%
# ['could', 'easily', 'retire'] - [while] vs [should]
# Iter= 5000, Average Loss= 1.805333, Average Accuracy= 58.90%
# ['know', 'when', 'she'] - [was] vs [.]
# Iter= 6000, Average Loss= 1.255559, Average Accuracy= 69.20%
# ['to', 'propose', 'that'] - [a] vs [a]
# Iter= 7000, Average Loss= 1.202641, Average Accuracy= 73.00%
# [',', 'if', 'we'] - [could] vs [could]
# Iter= 8000, Average Loss= 1.156721, Average Accuracy= 72.90%
# ['danger', 'consists', 'in'] - [the] vs [the]
# Iter= 9000, Average Loss= 0.954732, Average Accuracy= 75.30%
# ['which', 'he', 'thought'] - [would] vs [would]
# Iter= 10000, Average Loss= 0.798368, Average Accuracy= 80.30%
# ['the', 'cat', '.'] - [some] vs [by]
# Iter= 11000, Average Loss= 0.870950, Average Accuracy= 78.90%
# [',', 'the', 'mice'] - [had] vs [had]
# Iter= 12000, Average Loss= 0.842986, Average Accuracy= 79.20%
# ['spoke', '.', 'then'] - [the] vs [the]
# Iter= 13000, Average Loss= 0.631676, Average Accuracy= 85.20%
# ['the', 'cat', '?'] - [the] vs [the]
# Iter= 14000, Average Loss= 0.569058, Average Accuracy= 84.00%
# ['but', 'who', 'is'] - [to] vs [to]
# Iter= 15000, Average Loss= 0.646877, Average Accuracy= 84.50%
# ['general', 'applause', ','] - [until] vs [until]
# Iter= 16000, Average Loss= 0.543021, Average Accuracy= 85.60%
# ['could', 'easily', 'retire'] - [while] vs [while]
# Iter= 17000, Average Loss= 0.510662, Average Accuracy= 86.40%
# ['when', 'she', 'was'] - [about] vs [about]
# Iter= 18000, Average Loss= 0.446718, Average Accuracy= 88.80%
# ['neck', 'of', 'the'] - [cat] vs [cat]
# Iter= 19000, Average Loss= 0.448760, Average Accuracy= 88.80%
# ['escape', 'from', 'her'] - [.] vs [the]
# Iter= 20000, Average Loss= 0.476685, Average Accuracy= 86.60%
# ['enemy', 'approaches', 'us'] - [.] vs [.]
# Iter= 21000, Average Loss= 0.503716, Average Accuracy= 88.50%
# ['chief', 'danger', 'consists'] - [in] vs [in]
# Iter= 22000, Average Loss= 0.416823, Average Accuracy= 89.00%
# ['make', ',', 'which'] - [he] vs [he]
# Iter= 23000, Average Loss= 0.509394, Average Accuracy= 88.30%
# ['he', 'had', 'a'] - [proposal] vs [proposal]
# Iter= 24000, Average Loss= 0.410032, Average Accuracy= 89.80%
# [',', 'and', 'some'] - [said] vs [said]
# Iter= 25000, Average Loss= 0.255415, Average Accuracy= 92.60%
# ['long', 'ago', ','] - [the] vs [the]
# Iter= 26000, Average Loss= 0.413392, Average Accuracy= 90.50%
# ['mouse', 'said', 'it'] - [is] vs [is]
# Iter= 27000, Average Loss= 0.371763, Average Accuracy= 91.20%
# ['bell', 'the', 'cat'] - [?] vs [.]
# Iter= 28000, Average Loss= 0.322783, Average Accuracy= 91.80%
# ['retire', 'while', 'she'] - [was] vs [was]
# Iter= 29000, Average Loss= 0.371738, Average Accuracy= 91.30%
# ['ribbon', 'round', 'the'] - [neck] vs [neck]
# Iter= 30000, Average Loss= 0.297926, Average Accuracy= 93.00%
# [',', 'therefore', ','] - [to] vs [to]
# Iter= 31000, Average Loss= 0.302425, Average Accuracy= 91.60%
# ['from', 'her', '.'] - [i] vs [i]
# Iter= 32000, Average Loss= 0.233414, Average Accuracy= 93.10%
# ['manner', 'in', 'which'] - [the] vs [the]
# Iter= 33000, Average Loss= 0.288301, Average Accuracy= 92.80%
# ['meet', 'the', 'case'] - [.] vs [.]
# Iter= 34000, Average Loss= 0.318119, Average Accuracy= 93.80%
# ['he', 'had', 'a'] - [proposal] vs [proposal]
# Iter= 35000, Average Loss= 0.320845, Average Accuracy= 92.50%
# ['that', 'but', 'at'] - [last] vs [last]
# Iter= 36000, Average Loss= 0.240359, Average Accuracy= 92.70%
# ['their', 'common', 'enemy'] - [,] vs [,]
# Iter= 37000, Average Loss= 0.296366, Average Accuracy= 92.00%
# ['council', 'to', 'consider'] - [what] vs [what]
# Iter= 38000, Average Loss= 0.221997, Average Accuracy= 93.00%
# ['it', 'is', 'easy'] - [to] vs [to]
# Iter= 39000, Average Loss= 0.249358, Average Accuracy= 94.10%
# ['to', 'bell', 'the'] - [cat] vs [cat]
# Iter= 40000, Average Loss= 0.216031, Average Accuracy= 94.90%
# ['proposal', 'met', 'with'] - [general] vs [general]
# Iter= 41000, Average Loss= 0.256473, Average Accuracy= 94.00%
# ['retire', 'while', 'she'] - [was] vs [was]
# Iter= 42000, Average Loss= 0.293709, Average Accuracy= 93.10%
# ['the', 'cat', '.'] - [by] vs [some]
# Iter= 43000, Average Loss= 0.208028, Average Accuracy= 94.40%
# ['that', 'a', 'small'] - [bell] vs [bell]
# Iter= 44000, Average Loss= 0.201763, Average Accuracy= 94.50%
# ['could', 'easily', 'escape'] - [from] vs [from]
# Iter= 45000, Average Loss= 0.140982, Average Accuracy= 95.50%
# ['manner', 'in', 'which'] - [the] vs [the]
# Iter= 46000, Average Loss= 0.204964, Average Accuracy= 95.30%
# ['got', 'up', 'and'] - [said] vs [said]
# Iter= 47000, Average Loss= 0.131392, Average Accuracy= 96.30%
# ['council', 'to', 'consider'] - [what] vs [what]
# Iter= 48000, Average Loss= 0.221316, Average Accuracy= 94.90%
# ['easy', 'to', 'propose'] - [impossible] vs [impossible]
# Iter= 49000, Average Loss= 0.142243, Average Accuracy= 95.70%
# ['said', 'that', 'is'] - [all] vs [all]
# Iter= 50000, Average Loss= 0.140626, Average Accuracy= 96.10%
# ['while', 'she', 'was'] - [in] vs [in]
# Optimization Finished!
# Elapsed time:  55.98398602803548 min
# Run on command line.
# 	tensorboard --logdir=/tmp/tensorflow/rnn_words
# Point your web browser to: http://localhost:6006/
# 3 words: long ago ,
# long ago , the mice had a general council to consider what measures she was in the neighbourhood . you will all agree , said he , that our chief danger consists she was about
# 3 words: had a general
# had a general council to consider what measures she was in the neighbourhood . you will all agree , said he , that our chief danger consists she was about , and he said that
# 3 words: you will all
# you will all agree , said he , that our chief danger consists she was about , and he said that , and some said that , and some said that , and some said
# 3 words: why not you
# Word not in dictionary
# 3 words: why she was
# Word not in dictionary
# 3 words: about was she
# about was she approach , we could easily escape from her was in the neighbourhood . you will all agree , said he , that our chief danger consists she was about , and he
# 3 words: we could handle
# Word not in dictionary
# 3 words: handle we she
# Word not in dictionary
# 3 words: she could easily
# she could easily council from her was in the neighbourhood . you will all agree , said he , that our chief danger consists she was about , and he said that , and some
# 3 words: easily from us
# easily from us . now will all agree , said he , that our chief danger consists she was about , and he said that , and some said that , and some said that
# 3 words: some of us
# some of us well she mouse ribbon to propose impossible remedies . nobody what , therefore , to he , that our chief danger consists she was about , and he said that , and
